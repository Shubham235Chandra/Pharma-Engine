# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_csv("medicine_data.csv")

# %%
data.head(10)
# Out:
#           sub_category                                       product_name  \
# 0  Human Insulin Basal  Human Insulatard 40IU/ml Suspension for Injection
# 1  Human Insulin Basal                          Insulin 40IU/ml Injection
# 2  Human Insulin Basal                     Huminsulin N 40IU/ml Injection
# 3  Human Insulin Basal                        Insugen-N 40IU/ml Injection
# 4  Human Insulin Basal                        Insulatard 100IU/ml Flexpen
# 5  Human Insulin Basal                    Huminsulin N 100IU/ml Cartridge
# 6  Human Insulin Basal                    Huminsulin N 100IU/ml Injection
# 7  Human Insulin Basal                     Insulatard HM 100IU/ml Penfill
# 8  Human Insulin Basal                      Lupisulin N 40IU/ml Injection
# 9  Human Insulin Basal                 Insugen-N 100IU/ml Refil Injection
#
#               salt_composition product_price  \
# 0      Insulin Isophane (40IU)       ₹133.93
# 1      Insulin Isophane (40IU)       ₹121.91
# ...

# %%
data['salt']
# Out:
# 0         Human Insulatard 40IU/ml Suspension for Injection
# 1                                 Insulin 40IU/ml Injection
# 2                            Huminsulin N 40IU/ml Injection
# 3                               Insugen-N 40IU/ml Injection
# 4                               Insulatard 100IU/ml Flexpen
#                                 ...
# 195600                              Troykcl 1.5gm Injection
# 195601                             Ricetral 0.3gm Injection
# 195602                             Tuberium 150mg Injection
# 195603                                K-Pot 150mg Injection
# 195604                                Nervic-Plus Injection
# Name: product_name, Length: 195605, dtype: object

# %%
data['product_name'].split('+')
